# %%
import cv2 #to work with images
import numpy as np
from PIL import Image #for image-related work

# %%
image_path = r"T:\Orthopaedics\Lab Imaging Data\mmazur\DA_Model_Training\100X\100x DA model validation\Selected Images\4_BGW PNG\1503_CUNProx_100X_001.png"

img = cv2.imread(image_path, 0)

# %%
np.unique(img)
# Out:
# array([  0, 127, 255], dtype=uint8)
